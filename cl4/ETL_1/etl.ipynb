# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Global_Superstore2.csv",encoding='ISO-8859-1')
df.head()
# Out:
#    Row ID         Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891  31-07-2012  31-07-2012      Same Day    RH-19495
# 1   26341    IN-2013-77878  05-02-2013  07-02-2013  Second Class    JR-16210
# 2   25330    IN-2013-71249  17-10-2013  18-10-2013   First Class    CR-12730
# 3   13524  ES-2013-1579342  28-01-2013  30-01-2013   First Class    KM-16375
# 4   47221     SG-2013-4320  05-11-2013  06-11-2013      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#          Product ID    Category Sub-Category  \
# 0   TEC-AC-10003033  Technology  Accessories
# 1   FUR-CH-10003950   Furniture       Chairs
# 2   TEC-PH-10004664  Technology       Phones
# 3   TEC-PH-10004583  Technology       Phones
# 4  TEC-SHA-10000501  Technology      Copiers
#
#                                         Product Name     Sales Quantity  \
# 0  Plantronics CS510 - Over-the-Head monaural Wir...  2309.650        7
# 1          Novimex Executive Leather Armchair, Black  3709.395        9
# 2                  Nokia Smart Phone, with Caller ID  5175.171        9
# 3                     Motorola Smart Phone, Cordless  2892.510        5
# 4                     Sharp Wireless Fax, High-Speed  2832.960        8
#
#   Discount    Profit  Shipping Cost  Order Priority
# 0      0.0  762.1845         933.57        Critical
# 1      0.1 -288.7650         923.63        Critical
# 2      0.1  919.9710         915.49          Medium
# 3      0.1  -96.5400         910.16          Medium
# 4      0.0  311.5200         903.04        Critical
#
# [5 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  object
#  3   Ship Date       51290 non-null  object
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Postal Code     9994 non-null   float64
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
#  16  Sub-Category    51290 non-null  object
#  17  Product Name    51290 non-null  object
#  18  Sales           51290 non-null  float64
#  19  Quantity        51290 non-null  int64
#  20  Discount        51290 non-null  float64
#  21  Profit          51290 non-null  float64
#  22  Shipping Cost   51290 non-null  float64
#  23  Order Priority  51290 non-null  object
# dtypes: float64(5), int64(2), object(17)
# memory usage: 9.4+ MB

# %%
df.isnull().sum()
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# City                  0
# State                 0
# Country               0
# Postal Code       41296
# Market                0
# Region                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# dtype: int64

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# City              0
# State             0
# Country           0
# Postal Code       0
# Market            0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# Shipping Cost     0
# Order Priority    0
# dtype: int64

# %%
df.shape
# Out:
# (9994, 24)

# %%
df['Order Priority'].unique()
# Out:
# array(['Critical', 'Low', 'High', 'Medium'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
df.columns = df.columns.astype(str).str.strip()
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], dayfirst=True, errors='coerce')
df['Ship Date'] = pd.to_datetime(df['Ship Date'], dayfirst=True, errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9994 entries, 0 to 51287
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          9994 non-null   int64
#  1   Order ID        9994 non-null   object
#  2   Order Date      9994 non-null   datetime64[ns]
#  3   Ship Date       9994 non-null   datetime64[ns]
#  4   Ship Mode       9994 non-null   object
#  5   Customer ID     9994 non-null   object
#  6   Customer Name   9994 non-null   object
#  7   Segment         9994 non-null   object
#  8   City            9994 non-null   object
#  9   State           9994 non-null   object
#  10  Country         9994 non-null   object
#  11  Postal Code     9994 non-null   float64
#  12  Market          9994 non-null   object
#  13  Region          9994 non-null   object
#  14  Product ID      9994 non-null   object
#  15  Category        9994 non-null   object
#  16  Sub-Category    9994 non-null   object
#  17  Product Name    9994 non-null   object
#  18  Sales           9994 non-null   float64
#  19  Quantity        9994 non-null   int64
#  20  Discount        9994 non-null   float64
#  21  Profit          9994 non-null   float64
#  22  Shipping Cost   9994 non-null   float64
#  23  Order Priority  9994 non-null   object
# dtypes: datetime64[ns](2), float64(5), int64(2), object(15)
# memory usage: 1.9+ MB

# %%
df['Shipping Time (Days)'] = (df['Ship Date'] - df['Order Date']).dt.days
df.head()
# Out:
#     Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0    32298  CA-2012-124891 2012-07-31 2012-07-31        Same Day    RH-19495
# 8    40155  CA-2014-135909 2014-10-14 2014-10-21  Standard Class    JW-15220
# 9    40936  CA-2012-116638 2012-01-28 2012-01-31    Second Class    JH-15985
# 10   34577  CA-2011-102988 2011-04-05 2011-04-09    Second Class    GM-14695
# 16   36178  CA-2014-143567 2014-11-03 2014-11-06    Second Class    TB-21175
#
#     Customer Name    Segment           City           State  ...  \
# 0     Rick Hansen   Consumer  New York City        New York  ...
# 8       Jane Waco  Corporate     Sacramento      California  ...
# 9     Joseph Holt   Consumer        Concord  North Carolina  ...
# 10   Greg Maxwell  Corporate     Alexandria        Virginia  ...
# 16  Thomas Boland  Corporate      Henderson        Kentucky  ...
#
#            Category  Sub-Category  \
# 0        Technology   Accessories
# 8   Office Supplies       Binders
# 9         Furniture        Tables
# 10  Office Supplies      Supplies
# 16       Technology   Accessories
#
#                                          Product Name     Sales Quantity  \
# 0   Plantronics CS510 - Over-the-Head monaural Wir...  2309.650        7
# 8   Fellowes PB500 Electric Punch Plastic Comb Bin...  5083.960        5
# 9   Chromcraft Bull-Nose Wood Oval Conference Tabl...  4297.644       13
# 10  Martin Yale Chadless Opener Electric Letter Op...  4164.050        5
# 16                      Logitech diNovo Edge Keyboard  2249.910        9
#
#    Discount     Profit Shipping Cost  Order Priority  Shipping Time (Days)
# 0       0.0   762.1845        933.57        Critical                     0
# 8       0.2  1906.4850        867.69             Low                     7
# 9       0.4 -1862.3124        865.74        Critical                     3
# 10      0.0    83.2810        846.54            High                     4
# 16      0.0   517.4793        780.70        Critical                     3
#
# [5 rows x 25 columns]

# %%
priority_map = {'Low': 1, 'Medium': 2, 'High': 3, 'Critical': 4}
df['Priority_Level'] = df['Order Priority'].map(priority_map)
df.head()
# Out:
#     Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0    32298  CA-2012-124891 2012-07-31 2012-07-31        Same Day    RH-19495
# 8    40155  CA-2014-135909 2014-10-14 2014-10-21  Standard Class    JW-15220
# 9    40936  CA-2012-116638 2012-01-28 2012-01-31    Second Class    JH-15985
# 10   34577  CA-2011-102988 2011-04-05 2011-04-09    Second Class    GM-14695
# 16   36178  CA-2014-143567 2014-11-03 2014-11-06    Second Class    TB-21175
#
#     Customer Name    Segment           City           State  ... Sub-Category  \
# 0     Rick Hansen   Consumer  New York City        New York  ...  Accessories
# 8       Jane Waco  Corporate     Sacramento      California  ...      Binders
# 9     Joseph Holt   Consumer        Concord  North Carolina  ...       Tables
# 10   Greg Maxwell  Corporate     Alexandria        Virginia  ...     Supplies
# 16  Thomas Boland  Corporate      Henderson        Kentucky  ...  Accessories
#
#                                          Product Name     Sales Quantity  \
# 0   Plantronics CS510 - Over-the-Head monaural Wir...  2309.650        7
# 8   Fellowes PB500 Electric Punch Plastic Comb Bin...  5083.960        5
# 9   Chromcraft Bull-Nose Wood Oval Conference Tabl...  4297.644       13
# 10  Martin Yale Chadless Opener Electric Letter Op...  4164.050        5
# 16                      Logitech diNovo Edge Keyboard  2249.910        9
#
#    Discount     Profit Shipping Cost Order Priority  Shipping Time (Days)  \
# 0       0.0   762.1845        933.57       Critical                     0
# 8       0.2  1906.4850        867.69            Low                     7
# 9       0.4 -1862.3124        865.74       Critical                     3
# 10      0.0    83.2810        846.54           High                     4
# 16      0.0   517.4793        780.70       Critical                     3
#
#     Priority_Level
# 0                4
# 8                1
# 9                4
# 10               3
# 16               4
#
# [5 rows x 26 columns]

# %%
df.to_csv("Cleaned_dataset.csv")

# %%
dfc = pd.read_csv("Cleaned_dataset.csv")
dfc.head()
# Out:
#    Unnamed: 0  Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0           0   32298  CA-2012-124891  2012-07-31  2012-07-31        Same Day
# 1           8   40155  CA-2014-135909  2014-10-14  2014-10-21  Standard Class
# 2           9   40936  CA-2012-116638  2012-01-28  2012-01-31    Second Class
# 3          10   34577  CA-2011-102988  2011-04-05  2011-04-09    Second Class
# 4          16   36178  CA-2014-143567  2014-11-03  2014-11-06    Second Class
#
#   Customer ID  Customer Name    Segment           City  ... Sub-Category  \
# 0    RH-19495    Rick Hansen   Consumer  New York City  ...  Accessories
# 1    JW-15220      Jane Waco  Corporate     Sacramento  ...      Binders
# 2    JH-15985    Joseph Holt   Consumer        Concord  ...       Tables
# 3    GM-14695   Greg Maxwell  Corporate     Alexandria  ...     Supplies
# 4    TB-21175  Thomas Boland  Corporate      Henderson  ...  Accessories
#
#                                         Product Name     Sales Quantity  \
# 0  Plantronics CS510 - Over-the-Head monaural Wir...  2309.650        7
# 1  Fellowes PB500 Electric Punch Plastic Comb Bin...  5083.960        5
# 2  Chromcraft Bull-Nose Wood Oval Conference Tabl...  4297.644       13
# 3  Martin Yale Chadless Opener Electric Letter Op...  4164.050        5
# 4                      Logitech diNovo Edge Keyboard  2249.910        9
#
#   Discount     Profit Shipping Cost Order Priority Shipping Time (Days)  \
# 0      0.0   762.1845        933.57       Critical                    0
# 1      0.2  1906.4850        867.69            Low                    7
# 2      0.4 -1862.3124        865.74       Critical                    3
# 3      0.0    83.2810        846.54           High                    4
# 4      0.0   517.4793        780.70       Critical                    3
#
#    Priority_Level
# 0               4
# 1               1
# 2               4
# 3               3
# 4               4
#
# [5 rows x 27 columns]

# %%
dfc.columns
# Out:
# Index(['Unnamed: 0', 'Row ID', 'Order ID', 'Order Date', 'Ship Date',
#        'Ship Mode', 'Customer ID', 'Customer Name', 'Segment', 'City', 'State',
#        'Country', 'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority', 'Shipping Time (Days)',
#        'Priority_Level'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(df["Sales"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x11db09c08d0>,
#   <matplotlib.lines.Line2D at 0x11db09c1310>],
#  'caps': [<matplotlib.lines.Line2D at 0x11db09c1d10>,
#   <matplotlib.lines.Line2D at 0x11db09c2710>],
#  'boxes': [<matplotlib.lines.Line2D at 0x11db09b7ed0>],
#  'medians': [<matplotlib.lines.Line2D at 0x11db09c3150>],
#  'fliers': [<matplotlib.lines.Line2D at 0x11db09c3a90>],
#  'means': []}

# %%
plt.bar(df["Region"],df["Sales"])
# Out:
# <BarContainer object of 9994 artists>

# %%
import seaborn as sns
sns.histplot(df["Profit"],kde=True,bins=60)
# Out:
# <Axes: xlabel='Profit', ylabel='Count'>
